# %%
from keras.models import Sequential, Model
from keras import layers
from keras import Input
import numpy as np
# Out:
# Using TensorFlow backend.

# %%
# Build the sequential model first
seq_model = Sequential()
seq_model.add(layers.Dense(32, activation='relu', input_shape=(64,)))
seq_model.add(layers.Dense(32, activation='relu'))
seq_model.add(layers.Dense(10, activation='softmax'))
seq_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 32)                1056
# _________________________________________________________________
# dense_3 (Dense)              (None, 10)                330
# ...
# Total params: 3,466
# Trainable params: 3,466
# Non-trainable params: 0
# _________________________________________________________________

# %%
x_train = np.random.random((1024, 64))
y_train = np.random.random((1024, 10))

# %%
seq_model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['acc'])

# %%
history = seq_model.fit(x_train, y_train, validation_split=0.2, batch_size=128, epochs=5)
# Out:
# Train on 819 samples, validate on 205 samples
# Epoch 1/5
# 819/819 [==============================] - 0s - loss: 11.6070 - acc: 0.1099 - val_loss: 11.8314 - val_acc: 0.0878
# Epoch 2/5
# 819/819 [==============================] - 0s - loss: 11.5392 - acc: 0.0928 - val_loss: 11.8240 - val_acc: 0.0780
# Epoch 3/5
# 819/819 [==============================] - 0s - loss: 11.5269 - acc: 0.1136 - val_loss: 11.8154 - val_acc: 0.1073
# Epoch 4/5
# 819/819 [==============================] - 0s - loss: 11.5193 - acc: 0.1099 - val_loss: 11.8092 - val_acc: 0.0927
# Epoch 5/5
# 819/819 [==============================] - 0s - loss: 11.5141 - acc: 0.1270 - val_loss: 11.8076 - val_acc: 0.0683

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import utils

utils.plot(history, 'acc')

# %%
metric = 'acc'
train_accuracy = history.history[metric]
val_accuracy = history.history[f'val_{metric}']

train_loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = np.arange(1, len(train_accuracy) + 1)

plt.figure(figsize=(18, 5))

fig1 = plt.subplot(121)
fig1.plot(epochs, train_loss, 'g', label='Training loss')
fig1.plot(epochs, val_loss, 'r', label='Validation loss')
fig1.set_title('Loss', fontdict={'color':'w', 'size': 16})
fig1.tick_params(color='w', labelcolor='w')
fig1.set_xlabel('Epochs', fontdict={'color': 'r', 'size': 14})
fig1.set_ylabel('Loss', fontdict={'color': 'w', 'size': 14})
fig1.legend()

fig2 = plt.subplot(122)
y = epochs * 2
fig2.plot(epochs, y)

# %%
xtick_labels[0].label
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-e209560ab615> in <module>()
# ----> 1 xtick_labels[0].label
#
# NameError: name 'xtick_labels' is not defined
