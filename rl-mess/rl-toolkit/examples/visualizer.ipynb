# %%
import plotter as pltr
pltr.set_backend(pltr.MatplotlibBackend)

# %%
import functools
from rltk import Kit
import rltk.gridworld.grid_visualizer as gv
from frozen_lake import FrozenLake
from mlmetrics import SqliteMetric

# %%
kit = Kit.instance()
db = '/data/metrics/rl.db'
kit.metric = functools.partial(SqliteMetric, db=db)

# %%
gv.visualize_svals('blue-block-2849', FrozenLake.standard())
